# %% [markdown]
# ## Sher Market Stocks Prediction

# %% [markdown]
# pip install finnhub-python requests

# %%
import finnhub

client = finnhub.Client(api_key="d5ea399r01qjckl2qk40d5ea399r01qjckl2qk4g")
price = client.quote("AAPL")  # Apple stock
print(price)
# Out:
# {'c': 267.26, 'd': -3.75, 'dp': -1.3837, 'h': 271.51, 'l': 266.14, 'o': 270.64, 'pc': 271.01, 't': 1767646800}
